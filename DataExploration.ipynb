# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import datetime as dt
from sklearn import preprocessing as pp

# %%
dataFolder = r'C:\Users\upvarma\Documents\ML\demandForecasting\Data'
repoFolder = r'C:\Users\upvarma\Documents\ML\demandForecasting\demandForecasting'
#dataFolder = 
#repoFolder = 
outputFile = repoFolder + r'\output.txt'
os = open(outputFile, 'w')

# %%
#read input data files
train_df = pd.read_csv(dataFolder + r'\train.csv')
test_df = pd.read_csv(dataFolder + r'\test.csv')
holidaysEvents_df = pd.read_csv(dataFolder + r'\holidays_events.csv')
items_df = pd.read_csv(dataFolder + r'\items.csv')
oil_df = pd.read_csv(dataFolder + r'\oil.csv')
stores_df = pd.read_csv(dataFolder + r'\stores.csv')
transactions_df = pd.read_csv(dataFolder + r'\transactions.csv')
# Out:
# C:\Users\upvarma\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#looking at normalization within a family for various types of products
train_df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>store_nbr</th>
#       <th>item_nbr</th>
#       <th>unit_sales</th>
#       <th>onpromotion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>2013-01-01</td>
#       <td>25</td>
#       <td>103665</td>
#       <td>7.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2013-01-01</td>
#       <td>25</td>
#       <td>105574</td>
#       <td>1.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>2013-01-01</td>
#       <td>25</td>
# ...

# %%
sampleTrain_df = train_df.sample(frac= 0.0001)

# %%
normalized_df = sampleTrain_df.groupby(by=['item_nbr'])['unit_sales'].transform(lambda x: pp.maxabs_scale(x))

# %%
normalized_df.index.name = 'id'

# %%
sampleTrain_df.join(normalized_df, how='inner', rsuffix='_normalized')

# %%
pd.merge(sampleTrain_df, items_df, how='inner', on='item_nbr')
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>store_nbr</th>
#       <th>item_nbr</th>
#       <th>unit_sales</th>
#       <th>onpromotion</th>
#       <th>family</th>
#       <th>class</th>
#       <th>perishable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>80150292</td>
#       <td>2016-05-24</td>
#       <td>46</td>
#       <td>1693656</td>
#       <td>34.000</td>
#       <td>False</td>
#       <td>PRODUCE</td>
#       <td>2018</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>80005747</td>
#       <td>2016-05-23</td>
#       <td>14</td>
#       <td>1250226</td>
# ...
